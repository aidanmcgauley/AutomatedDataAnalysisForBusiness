# %% [markdown]
# # Chapter 1 - Conclusions

# %% [markdown]
# ## General setup

# %%
import docx
from docx import Document

import openai

openai.api_key = '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'

# %%
import torch
from transformers import AutoTokenizer

# %%
expert_interview_file_path = 'H:\Documents\Software Development\QUB Software Development\Data_analysis_module\ExpertInterview.docx'

# %%
AI_interview_file_path = 'H:\Documents\Software Development\QUB Software Development\Data_analysis_module\Chapter1ProjectReport.docx'

# %%
industry = "vintage banjo refurbishment and retail"

# %% [markdown]
# ## Functions

# %%
# Read in the file and chunk paragraphs if they exceed 2000 words

def read_word_file_2000(file_path):
    # Initialize a Document object
    document = Document(file_path)
    
    # Initialize a dictionary to store chunks
    chunk_dict = {}
    chunk_count = 1
    words_count = 0
    
    # Loop through each paragraph in the Document object
    for paragraph in document.paragraphs:
        # Ignore the paragraph if it's a heading or empty
        if paragraph.style.name.startswith('Heading') or paragraph.style.name.startswith('Title') or not paragraph.text.strip():
            continue
        
        # Count the words in the paragraph
        words_count += len(paragraph.text.split())

        # Check if the words count exceeds or equals 2000
        if words_count >= 2000:
            # Add the paragraph to the dictionary as a chunk
            chunk_dict[f'Chunk {chunk_count}'] = paragraph.text
            
            # Reset the words count and increment the chunk count
            words_count = 0
            chunk_count += 1
        else:
            # Add the paragraph to the current chunk
            chunk_dict.setdefault(f'Chunk {chunk_count}', '')
            chunk_dict[f'Chunk {chunk_count}'] += '\n' + paragraph.text
    
    return chunk_dict

# %%
# Using ChatGPT to summarise paragraphs

def summarize_paragraphs(paragraph_dict, prompt):
    openai.api_key = openai.api_key
    summarized_text = "" # initialize a string to store the summarized text

    for key, paragraph in paragraph_dict.items():
        print(f"Summarizing {key}")
        response = openai.ChatCompletion.create(
          model="gpt-3.5-turbo",
          messages=[
                {"role": "system", "content": prompt},
                {"role": "user", "content": paragraph},
            ]
        )
        # append the model's reply (i.e., the summary of the paragraph) to the summarized_text string
        summarized_text += "\n" + response['choices'][0]['message']['content']   
    
    return summarized_text

# %%
# Function that takes 2 docs to compare and contrast

def query_completion(doc1, doc2, prompt):
    openai.api_key = openai.api_key
    messages=[
        {"role": "system", "content": "You are an expert data analyst who always looks for the most promising areas of a business to investigate through data driven analysis."},
        {"role": "user", "content": f"Document 1: {doc1}"},
        {"role": "user", "content": f"Document 2: {doc2}"},
        {"role": "user", "content": prompt},
    ]

    response = openai.ChatCompletion.create(
      model="gpt-3.5-turbo",
      messages=messages
    )
    
    return response.choices[0].message['content']

# %%
# If it's necessary to check the tokens of summaries before passing back to chatgpt api:

def count_tokens(summary):
    # Initialize the tokenizer
    tokenizer = AutoTokenizer.from_pretrained("gpt2")

    # Encode the text into input IDs
    input_ids = torch.tensor(tokenizer.encode(summary)).unsqueeze(0)

    # Count the number of tokens
    num_tokens = input_ids.shape[1]

    print(f"Token count of the summarized text: {num_tokens}")
    return num_tokens

# %% [markdown]
# ## Read in both the expert interview and AI interview, then chunk them into smaller sections

# %%
# Split document in 2000 word chunks
expert_interview_chunked = read_word_file_2000(expert_interview_file_path)

# %%
# Split document in 2000 word chunks
AI_interview_chunked = read_word_file_2000(AI_interview_file_path)

# %%
# View chunked document
for key, value in expert_interview_chunked.items():
    print(f"{key}: {value}\n")
# Out:
# Chunk 1:
# The purchase, refurbishment, and sale of a vintage 1960’s Framus tenor banjo.
# The business owner’s wife is a banjo teacher whose students have always had trouble finding suitable instruments. Most students start off playing a new, budget instrument bought online in the sub £350 price bracket which they soon outgrow. There are no dealers in a 60 mile radius selling higher end, vintage banjos. Brand new instruments don’t have the same tonal qualities as older ones - the old wood is the secret.
# This project began with a search for any vintage banjo that the expert thinks customers are likely to want. Projects are typically not prompted by a specific request from a customer.
# There are a number of things the expert looks for when purchasing a banjo in need of restoration. The most important thing is the brand name - popular names played by famous players are what attract people to an instrument. Build quality is also important, and having experience with a variety of models over the years the expert knows which ones to look out for. After finding a 1963 Framus online from a German dealer (a good brand and year), the expert asked the vendor questions about the condition, playability, and whether there were any structural faults or repairs.
# If the vendor were to say the playability was bad (due to the action being too high), it could mean the neck is bent. This is the only defect that is not tolerated, and would eliminate a banjo from the possible candidates for purchase. Older banjos don’t have truss rods. From the experts' experience, it requires hours of work to insert a carbon rod to keep the neck straight. The fretboard must be removed, routed out for the new truss rod, and put back together again. It isn’t worth the man hours.
# In this case there were only minor defects which are perfectly acceptable when dealing in vintage instruments. There was a slight misalignment between the body and neck, some missing binding/inlay, and the metal components were slightly dulled/rusted in places. These defects are what drive the price down as the general public will avoid them.
# Before agreeing to purchase, the expert factored in the parts that may need to be purchased in order to bring it up to a sellable standard, as well as checking several sites for the current price guide for Framus banjos. They have a good idea of the price of Framus banjos in restored condition, but several websites are also checked for recent sale prices (Gruhn’s, Banjo Barn, Elderly Instruments).
# On this project, as with every project, the job that takes up the most time is sourcing the instrument - finding the banjo, dealing with the seller, and making sure it is successfully shipped.
# An estimate of the allocation of time on the project:
# 60% sourcing
# 20% refurbishing
# 20% marketing/selling
# By the time the banjo arrived in the post from Germany, the expert had all the additional parts and tools prepared to complete the job. The banjo was disassembled, the metal components were stripped, cleaned and polished, the ebony fretboard was cleaned and oiled, and the tuners were serviced to wind smoothly. Some new parts were fitted such as a new head/skin, a new bridge (ebony tipped maple), and new strings. Part of the binding was missing, so a new section had to be shaped and colour matched so as not to look out of place. The hardest part revolved around setting string action - it has to be correct for optimum playability, and comes down to fractions of a millimeter.  This is achieved during the final setup after the banjo has been reassembled. The string slots at the nut have to be filed down precisely, and the bridge has to be sanded down to the correct height.
# Overall the refurbishment was successful as the expert was able to find a banjo of a respected brand at a fair price, and once it was in his hands the refurbishment itself went smoothly. The purchase of a banjo is the biggest expense, followed by replacement parts, then paints/resins.
# According to the expert the only thing missing from this project was an original Framus skin. Many customers like to see the matching brand stamped on the skin, and it can increase the price of the instrument. The problem is that they are very rare, and could take up to 6 months to source one.
# When setting the price for the banjo, the expert factored in the initial price of the banjo, the cost of restoration including parts and labour, and profit margin. The markup typically ranges from 30-50%, in this case leaning toward the higher end. This strategy leaves room for deductions, as buyers often attempt to negotiate below the asking price.
# There are a number of ways in which potential customers find the business - through word of mouth, current banjo students, or on e-commerce websites. The expert relies on e-commerce sites to market an instrument as they don’t have a website, and don’t go out publicly to shows, festivals or exhibitions. The buyer of the Framus saw it advertised on Gumtree.
# There is a seasonality to banjo sales, with people treating themselves at Christmas time or during the summer when there are many competitions and festivals taking place.
# The business in this example is a one man operation, so the expert in question takes on all roles and responsibilities. They have experience in the following roles:
# Buying / purchasing
# Logistics
# Lutherie
# Sales
# An event that led to significant success for the expert’s business was the formation of a local music group offering lessons in various traditional Irish instruments, including the banjo. A teacher from the group got in touch when a student needed a banjo, and the expert quickly became the go-to source for the group. This not only boosted sales but also helped establish a stronger local presence for the expert's business.
# A significant challenge has arisen from external regulations. The introduction of the Convention on International Trade in Endangered Species (CITES) regulations on the overseas sales of exotic and hardwoods used in vintage instruments has drastically affected the import of stock from the United States. Prior to the enforcement of these regulations, a majority of the expert's stock was purchased from various American sources such as pawn shops, vintage shops, and online platforms like eBay. This is because USA made instruments are favoured by most players. Unfortunately, due to the strict regulatory environment, sellers have become increasingly hesitant to export these materials, shifting the source of procurement to closer locales. Germany is now the main source of stock, as they produced many quality instruments throughout the 20th century.
# The Brexit transition has further complicated matters. The confusion and hesitation surrounding new import regulations have caused sellers from mainland Europe to be reluctant about shipping goods to Northern Ireland. This is due to a lack of understanding about the specific arrangements Northern Ireland has under Brexit, where it remains part of the single market for goods. Therefore, sellers often assume they will be charged import charges similar to the rest of Britain. To mitigate this, the expert has had to resort to directly contacting sellers and clarifying the nuances of Brexit regulations regarding Northern Ireland.
# The things that players look for in a banjo have also changed over the past 15 to 20 years. Players nowadays prefer clear or black plastic skins for a more modern look, as opposed to the vintage looking goat skin.
# The general taste in tone has also changed. Players used to want a mellow, bassier tone, and now they want a sharper trebly sound.
# Lastly, nickel strings are now the preferred choice over bronze strings.
# Commonly held belief is that older wood and older banjos sound the best. Perhaps there are new builders who produce great sounding banjos, but the expert couldn’t name any off the top of their head. The same belief is held when it comes to other instruments such as guitar, but many of the greatest players and greatest recordings in history have been played on relatively new instruments. Perhaps it is a myth that old wood sounds the best, and the real reason for this preference is that banjos were simply built better in days gone by.

# %%
# View chunked document
for key, value in AI_interview_chunked.items():
    print(f"{key}: {value}\n")
# Out:
# Chunk 1:
#  Certainly, while it is unfortunate, there was a specific business in the vintage banjo refurbishment and retail industry that experienced a decline and eventually went out of business over the past 20 years. Let's consider the case of Banjo Revive Company (fictional name) and delve into the reasons for their failure.
#
# Banjo Revive Company was once a prominent player in the industry but struggled to adapt to changing market dynamics. One key factor that contributed to their downfall was their resistance to incorporating digital innovation into their business model. Unlike their competitors who embraced e-commerce and online platforms, Banjo Revive Company relied solely on traditional brick-and-mortar retail channels.
#
# In addition to their lack of digital presence, Banjo Revive Company failed to recognize the shifting preferences of customers towards more affordable options and DIY refurbishment. The rise of online banjo communities and forums paved the way for enthusiasts to share knowledge and resources. Many musicians began opting for less expensive, fixer-upper banjos and invested time and effort into refurbishing them themselves. Banjo Revive Company failed to tap into this trend and did not offer affordable options or support to these emerging customer segments.
#
# Furthermore, Banjo Revive Company did not keep pace with evolving customer expectations for customization and personalized experiences. They offered a limited range of models and customization options, while their competitors capitalized on the growing demand for customized banjos tailored to individual player preferences. This lack of adaptability and failure to stay on top of evolving customer desires diminished their appeal and led to a decline in market share.
#
# Finally, Banjo Revive Company failed to establish meaningful connections with banjo enthusiasts and musicians. Unlike successful businesses in the industry, they did not engage in community-building initiatives, sponsorship of events, or collaborations with influencers. This lack of connection and engagement with the banjo community further isolated them from potential customers and limited their reach.
#
# In summary, Banjo Revive Company's failure can be attributed to their reluctance to embrace digital innovation, lack of responsiveness to shifting customer preferences, failure to provide affordable options and support for DIY refurbishment, limited customization options, and a lack of community engagement. These factors collectively led to their decline and eventual market share plummet within the industry.
#
#
#
# Chunk 2:
#  For each of the metrics outlined in measuring the importance of quality refurbishment in the vintage banjo refurbishment and retail industry, here are the corresponding causal factors that can cause the metric to be higher or lower:
#
# 1. Customer Satisfaction:
#    - Higher: Superior craftsmanship, attention to detail in refurbishment process, meeting or exceeding customer expectations.
#    - Lower: Poor refurbishment quality, lack of attention to detail, failure to meet customer expectations.
#
# 2. Return Rate:
#    - Higher: Inadequate refurbishment quality, poor attention to detail, incorrect restoration procedures.
#    - Lower: High refurbishment quality, attention to detail, correct restoration techniques, meeting customer expectations.
#
# 3. Sales Growth:
#    - Higher: Positive reputation for quality refurbishment, word-of-mouth referrals, strong customer satisfaction.
#    - Lower: Poor refurbishment quality, negative word-of-mouth, decline in customer satisfaction.
#
# 4. Average Selling Price:
#    - Higher: Superior refurbishment quality, attention to detail, high customer demand, positive brand reputation.
#    - Lower: Inferior refurbishment quality, lack of attention to detail, low customer demand, negative brand perception.
#
# 5. Referral Rate:
#    - Higher: Exceptional refurbishment quality, customer satisfaction, positive reputation, strong customer relationships.
#    - Lower: Poor refurbishment quality, low customer satisfaction, negative reputation, lack of customer engagement.
#
# 6. Repair Frequency:
#    - Higher: Subpar refurbishment quality, inadequate attention to detail, improper restoration techniques.
#    - Lower: Superior refurbishment quality, attention to detail, correct restoration procedures.
#
# 7. Brand Reputation:
#    - Higher: Consistent delivery of high-quality refurbishment, positive customer experiences, positive reviews and recommendations.
#    - Lower: Inconsistent refurbishment quality, negative customer experiences, negative reviews or complaints.
#
# 8. Quality Control Measures:
#    - Higher: Comprehensive quality control processes, adherence to refurbishment standards, rigorous inspections and audits.
#    - Lower: Inadequate quality control procedures, lack of adherence to refurbishment standards, incomplete inspections.
#
# 9. Employee Training and Retention:
#    - Higher: Well-trained and experienced refurbishment technicians, continuous skill development, low turnover rate.
#    - Lower: Inadequate training, limited experience, high turnover rate of refurbishment staff.
#
# 10. Market Share:
#     - Higher: Excellent refurbishment quality, competitive pricing, strong customer satisfaction, positive industry reputation.
#     - Lower: Inferior refurbishment quality, high prices without added value, negative customer experiences, poor industry reputation.
#
# These causal factors directly impact the measured metrics and can determine whether they are higher or lower, showcasing the influence of quality refurbishment on the success of businesses in the vintage banjo refurbishment and retail industry.
#
#
#
# Chunk 3:
#  In the vintage banjo refurbishment and retail industry, there might be several commonly held beliefs or practices that have not been critically examined or challenged. These unquestioned assumptions could include:
#
# 1. Restoring vintage banjos to their original condition yields higher sales: It is often believed that fully restoring a vintage banjo to its original condition increases its value and marketability. However, there might be a lack of data or metrics to support this assumption. Analyzing sales data based on the condition of refurbished banjos and their corresponding prices could shed light on the actual impact of restoration on sales.
#
# 2. Traditional marketing methods are sufficient for attracting customers: Many businesses in this industry might rely heavily on traditional marketing methods, such as print advertisements, word of mouth, or attending banjo-related events. However, it is essential to critically examine whether these methods effectively reach and attract the target audience. Collecting data on customer acquisition channels and their conversion rates could provide insights into the effectiveness of traditional marketing practices.
#
# 3. Limited edition or rare banjos guarantee higher profits: It is commonly believed that acquiring and selling limited edition or rare banjos will result in higher profits. However, this assumption should be challenged by evaluating the market demand for these types of banjos and analyzing the actual profit margins associated with their sale. Collecting data on sales and profitability of limited edition or rare banjos compared to regular models can reveal the true impact on business success.
#
# 4. Networking within the banjo community is essential for business growth: The belief that actively participating in banjo-related events, conferences, or forums is crucial for building industry connections and driving business growth might go unquestioned. However, it is valuable to critically examine the impact of networking efforts on actual business outcomes. Tracking and analyzing conversion rates or customer referrals resulting from networking activities could provide clarity on the effectiveness of this belief.
#
# 5. Providing a wide range of banjo accessories enhances customer satisfaction: Many businesses within the banjo industry offer a wide range of accessories, such as strings, picks, cases, and straps, assuming that this enhances customer satisfaction and drives repeat business. However, this belief should be challenged by analyzing customer feedback and sales data. Understanding the correlation between accessory sales and customer satisfaction or repeat purchases can gauge the true impact on the business.
#
# Overall, these unquestioned assumptions in the vintage banjo refurbishment and retail industry can be critically examined by collecting relevant data and analyzing metrics related to sales, profitability, customer acquisition, customer satisfaction, and repeat business. By challenging these assumptions, potential areas for improvement or untapped opportunities for success can be identified.
#
#
#
# Chunk 4:
#  One assumption or myth in the vintage banjo refurbishment and retail industry that might be worth investigating is the belief that higher prices equate to higher quality. It is commonly assumed that customers are willing to pay more for banjos that have a higher price tag because they perceive them to be of superior quality.
#
# To investigate this assumption, one could conduct a survey or interview customers to understand their purchasing behavior and preferences. Questions could focus on factors that influence their decision-making process when it comes to purchasing banjos, such as the significance of price and perceived quality.
#
# Additionally, analyzing sales data and customer reviews can provide insights into the relationship between price and customer satisfaction. By examining whether higher-priced banjos consistently receive better reviews or generate more repeat customers, one can determine if the assumption holds true or if customers prioritize other factors beyond price.
#
# To leverage commonly held beliefs and myths in the industry, existing businesses could:
#
# 1. Emphasize restoration expertise: If the belief that restoring vintage banjos to their original condition leads to higher sales still holds sway, businesses can emphasize their restoration expertise to differentiate themselves from competitors. Demonstrating a track record of successfully restoring and enhancing the quality of these instruments can build trust and attract customers who prioritize quality.
#
# 2. Showcase limited edition or rare banjos: If the assumption that limited edition or rare banjos guarantee higher profits is prevalent, businesses can invest in acquiring and showcasing these unique instruments. By creating a reputation for offering exclusive and sought-after banjos, businesses can attract collectors or enthusiasts willing to pay a premium.
#
# 3. Cultivate strong industry relationships: If networking within the banjo community is considered essential for business growth, businesses can actively engage in banjo-related events, conferences, and forums. By establishing strong industry relationships, businesses may gain access to exclusive opportunities, collaborations, or referrals from industry experts or influencers.
#
# 4. Offer a comprehensive range of banjo accessories: If the belief that providing a wide range of banjo accessories enhances customer satisfaction persists, businesses can ensure they have a diverse selection of high-quality accessory offerings. This can be achieved by identifying popular brands or types of accessories preferred by banjo players and incorporating them into the product lineup.
#
# However, it is crucial for businesses to continually reassess these beliefs and myths in light of changing consumer preferences and market dynamics. Critical examination and data analysis should be an ongoing process to identify any potential shifts in customer behavior and to adapt business strategies accordingly.

# %% [markdown]
# ## Summarise both interviews

# %%
prompt = f"""You are an expert in data analysis and you are helping a business 
            in the {industry} industry become more successful and increase revenue.
            You have to read the following interview excerpt with the owner of the business.
            The interview includes details about a recent project,
            and discussion with an expert about the wider industry.
            Suggest the key areas you think could lead to 
            the most impactful recommendations for the business 
            through a data analysis investigation, 
            and summarise your conclusions. """

# %% [markdown]
# *In the interest of keeping the report short I just used the prompt above to summarise the interviews.*
#
# *If you wanted more information, the prompt below could be looped over, changing the 'top_5' parameter each time.*

# %%
# Parameterised prompting
top_5_priority = "values of the business"
#top_5_priority = "challenges for the business"
#top_5_priority = "potentially unexplored revenue streams"
#top_5_priority = "weaknesses of the management team"
#top_5_priority = "impactful recommendations to help the business succeed"

parameter_prompt = f"""You are an expert in data analysis and you are helping a business 
            in the {industry} industry become more successful and increase revenue.
            You have to read the following interview excerpt with the owner of the business.
            The interview includes details about a recent project,
            and discussion with an expert about the wider industry.
            Upon reviewing the interview,
            outline the top 5 {top_5_priority}."""

# %%
# Summary of all chunks of expert interview
expert_summary = summarize_paragraphs(expert_interview_chunked, prompt)
# Out:
# Summarizing Chunk 1

# %%
# Summary of all chunks of AI generated report
AI_interview_summary = summarize_paragraphs(AI_interview_chunked, prompt)
# Out:
# Summarizing Chunk 1
# Summarizing Chunk 2
# Summarizing Chunk 3
# Summarizing Chunk 4

# %%
# View summary
print("\nSummary of the document:\n")
print(expert_summary)
# Out:
# Summary of the document:
#
#
# Based on the interview excerpt, the following key areas could lead to impactful recommendations for the business through a data analysis investigation:
#
# 1. Market Research: Conducting market research to understand the demand for vintage banjos in the local area and identifying potential customers who are interested in purchasing higher-end instruments.
#
# 2. Customer Preferences: Analyzing customer preferences and trends in the banjo industry over the past 15 to 20 years. This would involve understanding changes in preferred skin type, tone preferences, and string choices. This data can help the business tailor their refurbishment process and product offerings to meet customer preferences.
#
# 3. Pricing Strategy: Analyzing the pricing strategy for refurbished vintage banjos. This would involve analyzing the initial purchase price of banjos, cost of restoration including parts and labor, and the desired profit margin. Additionally, understanding the price range at which customers are willing to purchase banjos can help in setting competitive prices.
#
# 4. Marketing Channels: Analyzing the effectiveness of different marketing channels, such as e-commerce websites, word of mouth, and potential partnerships with local music groups or banjo teachers. This analysis can help the business identify the most effective channels for reaching potential customers and allocate resources accordingly.
#
# 5. Sourcing Challenges: Investigating the impact of external regulations, such as CITES regulations and Brexit, on procurement and importation of banjos. Understanding the challenges faced in sourcing banjos from different regions can help the business identify alternative sourcing strategies or potential partnerships with suppliers.
#
# 6. Competition Analysis: Analyzing the market for new builders who produce high-quality banjos. This would involve identifying competitors in the market and assessing their reputation and customer satisfaction. This analysis can help the business identify potential collaborations or partnerships with new builders to expand their product offerings.
#
# 7. Time Allocation: Analyzing the time allocation for different stages of the refurbishment process, such as sourcing, refurbishing, and marketing/selling. This analysis can help identify potential areas for optimization and increased efficiency in order to reduce costs or increase productivity.
#
# Conclusions:
# Based on the interview excerpt, the business's success is heavily dependent on the sourcing and refurbishment process. Therefore, conducting market research, including customer preferences and pricing analysis, can help the business tailor their offerings to meet customer demands and set competitive prices. Additionally, understanding the impact of external regulations on sourcing and importation can help the business explore alternative sourcing strategies and partnerships. Optimizing time allocation and analyzing marketing channels can also help increase efficiency and reach potential customers effectively.

# %%
# View summary
print("\nSummary of the document:\n")
print(AI_interview_summary)
# Out:
# Summary of the document:
#
#
# Based on the interview, here are the key areas that could lead to the most impactful recommendations for the business:
#
# 1. Embrace digital innovation: The business needs to incorporate e-commerce and online platforms to reach a wider customer base. This would allow the business to tap into the growing trend of online banjo communities and forums and provide customers with more affordable options and support for DIY refurbishment.
#
# 2. Offer affordable options and support for DIY refurbishment: Recognize the shifting preferences of customers towards fixer-upper banjos and invest in providing affordable options and resources for customers to refurbish banjos themselves. This could involve offering lower-priced banjo models or refurbishment kits.
#
# 3. Provide customization options: Adapt to evolving customer expectations by offering a wider range of banjo models and customization options. This will appeal to customers who are looking for banjos tailored to their specific preferences and increase the business's competitiveness in the market.
#
# 4. Engage with the banjo community: Establish meaningful connections with banjo enthusiasts and musicians through community-building initiatives, event sponsorships, and collaborations with influencers. This will help the business build brand awareness, expand its reach, and create a loyal customer base.
#
# In conclusion, the business should prioritize digital innovation, affordability, customization, and community engagement to increase revenue and succeed in the vintage banjo refurbishment and retail industry. By embracing these key areas, the business can adapt to changing market dynamics, meet customer expectations, and differentiate itself from competitors.
# Based on the interview excerpt, there are several key areas that could lead to impactful recommendations for the business through data analysis investigation:
#
# 1. Refurbishment Quality: The interview highlights the importance of refurbishment quality on metrics such as customer satisfaction, return rate, sales growth, and average selling price. Investigating the refurbishment process, identifying areas for improvement, and monitoring quality control measures could lead to recommendations for enhancing refurbishment quality.
#
# 2. Customer Satisfaction: Understanding customer expectations, tracking customer feedback and reviews, and analyzing data on customer satisfaction could provide insights into improving the overall customer experience. This could include aspects such as communication, timely delivery, and meeting customer preferences.
#
# 3. Employee Training and Retention: Investigating the impact of employee training and experience on refurbishment quality could provide recommendations for improving the skills and expertise of refurbishment technicians. Additionally, analyzing turnover rates and implementing measures to improve employee retention could lead to a more consistent and skilled workforce.
#
# 4. Market Share: Analyzing market trends, competitor pricing strategies, and customer preferences could provide recommendations for enhancing the business's competitive position and increasing market share. This could include exploring opportunities to differentiate the business through unique refurbishment offerings, competitive pricing, and effective marketing strategies.
#
# 5. Brand Reputation: Monitoring customer reviews, social media sentiment, and industry reputation could provide insights into the overall perception of the business. Data analysis could help in identifying potential areas of improvement in refurbishment quality, customer satisfaction, and overall brand image.
#
# 6. Repair Frequency: Analyzing data on repair frequency and identifying common issues or patterns could provide recommendations for improving refurbishment quality and addressing potential areas of concern.
#
# In conclusion, a data analysis investigation focused on refurbishment quality, customer satisfaction, employee training, market share, brand reputation, and repair frequency could uncover valuable insights and lead to impactful recommendations for the business in the vintage banjo refurbishment and retail industry. Implementing these recommendations could help increase revenue, enhance customer satisfaction, and improve the overall success of the business.
# From the interview excerpt with the owner of the business, the key areas that could lead to the most impactful recommendations for the business through data analysis investigation are as follows:
#
# 1. Conversion rate analysis: The owner mentioned that they have seen an increase in website traffic, but the conversion rate has not improved. Analyzing website data and measuring conversion rates can provide insights into potential issues in the sales funnel or user experience that are hindering conversions. By identifying these issues, the business can make data-driven improvements to increase conversion rates and ultimately drive more sales.
#
# 2. Customer segmentation and targeting: The owner also mentioned that most of their customers are experienced banjo players who refurbish and resell the instruments. Analyzing customer data, such as demographics, purchase history, and behavior, can help in creating customer segments and better understanding the target audience. This can enable the business to tailor marketing strategies and product offerings to specific customer groups, potentially attracting new customers and increasing sales.
#
# 3. Market demand analysis: The expert mentioned that there is a trend of younger people becoming interested in vintage banjos. Conducting market research and analyzing industry trends can help the business identify potential growth opportunities and tailor their marketing efforts to attract this new demographic. This analysis can also inform decisions regarding the types of banjos to refurbish or stock, based on current market demand.
#
# 4. Pricing strategy optimization: The owner mentioned that they price banjos based on their investment in refurbishment, but they acknowledge that pricing could be a challenge. Conducting a pricing analysis based on factors such as market demand, competitor pricing, and customer perception can help optimize the pricing strategy. This analysis can provide insights into whether price adjustments, discounts, or bundling options can be applied to increase sales and competitiveness.
#
# 5. Customer satisfaction analysis: The owner mentioned that they have received positive feedback from customers, but there is room for improvement. Implementing customer satisfaction surveys or analyzing customer feedback can help identify areas where improvements can be made to enhance the overall customer experience. This analysis can also identify potential opportunities for upselling or cross-selling additional products or services.
#
# In conclusion, by conducting data analysis in areas such as conversion rates, customer segmentation, market demand, pricing strategy, and customer satisfaction, the business can gain valuable insights and make data-driven recommendations to increase revenue and improve overall success in the vintage banjo refurbishment and retail industry.
# Based on the interview excerpt, there are several key areas that could lead to impactful recommendations for the business through data analysis:
#
# 1. Customer preferences: Analyzing customer data such as purchasing behavior and preferences can provide insights into what drives customers to make a purchase. This could include factors such as price, brand reputation, product features, or vintage authenticity. Understanding these preferences can help the business tailor their product offerings and marketing strategies to better align with customer needs.
#
# 2. Pricing strategy: Investigating the relationship between price and customer satisfaction can help the business optimize their pricing strategy. By analyzing sales data and customer reviews, the business can determine if higher-priced banjos consistently generate higher customer satisfaction or if there is a sweet spot in terms of pricing that maximizes both sales and customer satisfaction.
#
# 3. Market trends: Researching and analyzing market trends in the vintage banjo industry can help the business stay ahead of the competition and identify new opportunities for growth. This could include tracking demand for specific brands or models, monitoring changes in customer preferences, or identifying emerging market segments.
#
# 4. Competitor analysis: Analyzing data on competitors can provide insights into their strategies, pricing, and customer base. This can help the business identify areas where they can differentiate themselves and gain a competitive advantage, such as offering unique services or targeting specific customer segments that are underserved by competitors.
#
# 5. Customer segmentation: Segmenting customers based on factors such as demographics, purchasing behavior, or preferences can help the business tailor their marketing efforts and product offerings to different customer segments. By understanding the unique needs and preferences of each segment, the business can better target their messaging and allocate resources effectively.
#
# Based on the above areas of investigation, the following conclusions can be drawn:
#
# - Price does not necessarily equate to higher quality in the eyes of customers. Other factors such as brand reputation, vintage authenticity, and product features may also play a significant role in customers' purchasing decisions.
#
# - The business should focus on providing a diverse range of banjo accessories to enhance customer satisfaction. Identifying popular accessory brands and incorporating them into their product lineup can help attract customers and increase revenue.
#
# - Cultivating strong industry relationships and actively engaging in banjo-related events can help the business gain access to exclusive opportunities, collaborations, or referrals from industry experts and influencers.
#
# - The business should continuously reassess and adapt their strategies based on changing consumer preferences and market dynamics to ensure long-term success. Regular data analysis and monitoring of market trends and customer behavior are essential for identifying any shifts or opportunities in the industry.

# %% [markdown]
# ## Compare and contract the interviews, and draw conclusions

# %%
prompt = f"""You are an expert data analyst. You help businesses to succeed by analysing data
            and finding novel, counter-intuitive suggestions to make improvements and increase revenue.
            I have summarised the main points 
            from interviews with 2 business owners in the {industry} industry.
            Can you compare and contrast them?
            As an expert in data analysis, what data would you focus on gathering 
            after reading a summary of both interviews?"""

# %%
conclusion = query_completion(expert_summary, AI_interview_summary, prompt)

# %%
print(conclusion)
# Out:
# Certainly! Let's compare and contrast the main points from the interviews with the business owners in the vintage banjo refurbishment and retail industry:
#
# Business Owner 1 (Document 1):
# - Key areas for analysis highlighted include market research, customer preferences, pricing strategy, marketing channels, sourcing challenges, competition analysis, and time allocation.
# - The emphasis is on market research, understanding customer preferences and trends, optimizing pricing strategies, analyzing marketing channels, and addressing challenges in sourcing and competition.
#
# Business Owner 2 (Document 2):
# - Key areas for analysis highlighted include digital innovation, affordability, customization, and community engagement.
# - The focus is on embracing e-commerce and online platforms, providing affordable options for self-refurbishment, offering customization, and engaging with the banjo community.
#
# Although both interview excerpts provide valuable insights, they differ in their recommendations for improvement. Business Owner 1's suggestions focus on traditional market analysis, while Business Owner 2 emphasizes the need for digital innovation and community engagement. Additionally, Business Owner 1 discusses the challenges related to sourcing and refurbishment processes, while Business Owner 2 emphasizes affordability and customization options.
#
# After reading a summary of both interviews, as an expert data analyst, I would focus on gathering the following data:
#
# 1. Market research data: This would involve collecting data on banjo demand, customer demographics, and preferences in the local area. Understanding the market size, target customer segments, and competitive landscape is essential.
#
# 2. Sales and customer data: Analyzing sales data, customer feedback, and customer satisfaction metrics would provide insights into factors driving customer preferences, purchasing behavior, and overall satisfaction. This could include data on conversion rates, average order value, and return rates.
#
# 3. Pricing data: Collecting data on pricing strategy, competitive pricing, and customer perception of pricing would be important for optimizing pricing strategies. This could involve analyzing historical pricing data, surveying customers for their perception of value, and tracking competitor pricing.
#
# 4. Website analytics: Gathering data on website traffic, conversion rates, and user behavior can provide insights into potential user experience issues or bottlenecks in the sales funnel. This data can help identify areas for improvement and optimization.
#
# 5. Social media and sentiment analysis: Analyzing social media engagement, sentiment analysis, and customer reviews can provide insights into brand reputation and customer satisfaction. This data can help identify areas for improvement and potential strategies for engaging with the banjo community.
#
# 6. Competitor analysis: Collecting data on competitors, including their product offerings, pricing, and customer satisfaction metrics, can provide insights into market trends, potential collaborations, and areas for differentiation.
#
# By focusing on gathering and analyzing these types of data, we can uncover valuable insights to make data-driven recommendations for improving the business's performance, increasing revenue, and enhancing customer satisfaction in the vintage banjo refurbishment and retail industry.

# %% [markdown]
# ## Finally, construct the word document

# %%
# Now add real expert interview and conclusion section to the project report

# %%
document = Document('H:\Documents\Software Development\QUB Software Development\Data_analysis_module\Chapter1ProjectReport.docx')

# %%
document.add_heading("1.5. Summary of an interview with a real industry expert", 2)

# %%
document.add_paragraph(expert_summary)

# %%
document.add_heading("1.6. Conclusions", 2)

# %%
document.add_paragraph("AI generated comparison between expert interview and AI generated report, and final conclusions:\n")

# %%
document.add_paragraph(conclusion)

# %%
document.save('H:\Documents\Software Development\QUB Software Development\Data_analysis_module\Chapter1ProjectReport.docx')
